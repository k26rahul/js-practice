# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('UnstoppableHer (Responses) - Form Responses 1.csv')
# df['Events in which you would like to participate']

# %%
filtered_df = df[df['Events in which you would like to participate'].str.contains('Stree', na=False)]

len(filtered_df)

# filtered_df
# Out:
# 52

# %%
filtered_df = filtered_df.dropna(subset=['Email Address'])
len(filtered_df)
# Out:
# 51

# %%
info_df = filtered_df[['Email Address', 'Whatsapp Number']]

len(info_df)
info_df

info_df.to_csv('stree_sakti_quiz_participants.csv', index=False)
# Out:
# 51
#                       Email Address Whatsapp Number
# 0    24f3004596@ds.study.iitm.ac.in      9390134779
# 2    24f3001446@ds.study.iitm.ac.in      9346666132
# 16   23f3000095@es.study.iitm.ac.in      7878434435
# 21   23f3001151@ds.study.iitm.ac.in      9895371065
# 25   23f3000797@ds.study.iitm.ac.in      8707643407
# 26   23f3000114@ds.study.iitm.ac.in      8960608880
# 35   23f3003784@ds.study.iitm.ac.in      7008090790
# 37   24f2008109@ds.study.iitm.ac.in      6388717578
# 40   24f2001941@ds.study.iitm.ac.in      9729491710
# 41   24f2007584@ds.study.iitm.ac.in      9058943962
# 43   22f3000419@ds.study.iitm.ac.in      7669967479
# 50   23f3003643@ds.study.iitm.ac.in      9917275339
# 52   24f1002463@ds.study.iitm.ac.in      9632391547
# 54   23f2005039@ds.study.iitm.ac.in      9472439782
# 65   24f2007051@ds.study.iitm.ac.in      7738375090
# 71   24f3001732@ds.study.iitm.ac.in      6263912116
# 78   24f2100374@es.study.iitm.ac.in      8957740379
# ...
